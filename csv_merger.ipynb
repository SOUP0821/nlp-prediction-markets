# %%
import pandas as pd

# %%
csv1 = r''
csv2 = r''
topic = ''

df1 = pd.read_csv(csv1)
df2 = pd.read_csv(csv2)

df1 = df1[['timestamp', 'text']]
df2 = df2.rename(columns={'pubDate':'timestamp', 'title':'text'})

df3 = pd.concat([df1,df2], ignore_index=True)

df3.to_csv(f'{topic}_complete_data.csv', index=False)
